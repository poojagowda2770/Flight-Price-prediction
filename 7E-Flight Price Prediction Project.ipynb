# %% [markdown]
# # Flight Price Prediction Project:

# %% [markdown]
# Submitted by POOJA C Batch No:1831

# %% [markdown]
# **STATEMENT: Flight ticket prices can be something hard to guess, today we might see a price, check out the price of the same flight tomorrow, it will be a different story. We might have often heard travellers saying that flight ticket prices are so unpredictable. Here you will be provided with prices of flight tickets for various airlines between the months of March and June of 2019 and between various cities.**

# %% [markdown]
# # Importing datasets:

# %%
#importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

import warnings
warnings.filterwarnings('ignore')

# %%
#importing train dataset
df = pd.read_excel("Data_Train.xlsx") #Reading excel file
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
#importing test dataset
dff = pd.read_excel("Test_set.xlsx") #Reading excel file
dff.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %% [markdown]
# Above are my train and test datasets and the target is seems to be price so this perticular problem is a **Regression problem.**

# %% [markdown]
# # Features Information:

# %% [markdown]
# - Airline: The name of the airline.
# - Date_of_Journey: The date of the journey
# - Source: The source from which the service begins.
# - Destination: The destination where the service ends.
# - Route: The route taken by the flight to reach the destination.
# - Dep_Time: The time when the journey starts from the source.
# - Arrival_Time: Time of arrival at the destination.
# - Duration: Total duration of the flight.
# - Total_Stops: Total stops between the source and destination.
# - Additional_Info: Additional information about the flight
# - Price: The price of the ticket

# %% [markdown]
# # i) Train dataset:

# %% [markdown]
# # Preprocessing and EDA:

# %%
#Checking shape of my dataset
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# In my tarin dataset i have 10683 rows and 11 columns.

# %%
#Checking all column names
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# Above are the column names of the train dataset.

# %%
#Checking the data types of all columns
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# Except Price all other columns are object type datas.But i have to convert date of journey, dep_time and arrival_time columns from object to datetime type data.

# %%
#Checking the info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# - There are nan values in Route and Total_Stops columns.

# %%
#Checking unique values of each column
df.nunique()
# Out:
# Airline              12
# Date_of_Journey      44
# Source                5
# Destination           6
# Route               128
# Dep_Time            222
# Arrival_Time       1343
# Duration            368
# Total_Stops           5
# Additional_Info      10
# Price              1870
# dtype: int64

# %% [markdown]
# Above are the unique value counts of each column.

# %%
#Lets check the value count of each column to see if there are any unexpected and unwanted entries present in the column.
for i in df.columns:
        print(df[i].value_counts())
        print('****************************************')
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64
# ****************************************
# 18/05/2019    504
# 6/06/2019     503
# 21/05/2019    497
# 9/06/2019     495
# 12/06/2019    493
# 9/05/2019     484
# 21/03/2019    423
# 15/05/2019    405
# 27/05/2019    382
# 27/06/2019    355
# 24/06/2019    351
# 1/06/2019     342
# 3/06/2019     333
# 15/06/2019    328
# 24/03/2019    323
# 6/03/2019     308
# 27/03/2019    299
# 24/05/2019    286
# 6/05/2019     282
# 1/05/2019     277
# 12/05/2019    259
# 1/04/2019     257
# 3/03/2019     218
# 9/03/2019     200
# 15/03/2019    162
# 18/03/2019    156
# 01/03/2019    152
# 12/03/2019    142
# 9/04/2019     125
# 3/04/2019     110
# 21/06/2019    109
# 18/06/2019    105
# 09/03/2019    102
# 6/04/2019     100
# 03/03/2019     97
# 06/03/2019     95
# 27/04/2019     94
# 24/04/2019     92
# 3/05/2019      90
# 15/04/2019     89
# 21/04/2019     82
# 18/04/2019     67
# 12/04/2019     63
# 1/03/2019      47
# Name: Date_of_Journey, dtype: int64
# ****************************************
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64
# ****************************************
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64
# ****************************************
# DEL → BOM → COK                      2376
# BLR → DEL                            1552
# CCU → BOM → BLR                       979
# CCU → BLR                             724
# BOM → HYD                             621
#                                      ...
# CCU → VTZ → BLR                         1
# BLR → CCU → BBI → HYD → VGA → DEL       1
# CCU → IXA → BLR                         1
# BOM → BLR → CCU → BBI → HYD             1
# BLR → BOM → IXC → DEL                   1
# Name: Route, Length: 128, dtype: int64
# ****************************************
# 18:55    233
# 17:00    227
# 07:05    205
# 10:00    203
# 07:10    202
#         ...
# 16:25      1
# 12:05      1
# 03:00      1
# 21:35      1
# 22:25      1
# Name: Dep_Time, Length: 222, dtype: int64
# ****************************************
# 19:00           423
# 21:00           360
# 19:15           333
# 16:10           154
# 12:35           122
#                ...
# 00:15 22 Mar      1
# 11:05 10 Apr      1
# 00:50 13 Apr      1
# 07:45 16 May      1
# 02:20 04 May      1
# Name: Arrival_Time, Length: 1343, dtype: int64
# ****************************************
# 2h 50m     550
# 1h 30m     386
# 2h 55m     337
# 2h 45m     337
# 2h 35m     329
#           ...
# 32h 55m      1
# 42h 45m      1
# 28h 30m      1
# 35h 35m      1
# 29h 10m      1
# Name: Duration, Length: 368, dtype: int64
# ****************************************
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64
# ****************************************
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# Red-eye flight                     1
# 2 Long layover                     1
# 1 Short layover                    1
# Name: Additional_Info, dtype: int64
# ****************************************
# 10262    258
# 10844    212
# 7229     162
# 4804     160
# 4823     131
#         ...
# 9502       1
# 13875      1
# 7742       1
# 5703       1
# 4098       1
# Name: Price, Length: 1870, dtype: int64
# ****************************************

# %% [markdown]
# Above are the value counts of each column.

# %%
#Checking null values in the dataset
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# There are only one nan values in Route and Total_Stops column.

# %% [markdown]
# # Imputation technique to replace nan values:

# %%
#Replacing naa values with there mode as those two columns are categorical
df["Route"] = df["Route"].fillna(df["Route"].mode()[0])
df["Total_Stops"] = df["Total_Stops"].fillna(df["Total_Stops"].mode()[0])

# %%
#Checking null values again
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# Now all the nan values has been replaced.

# %%
#Checking unique values of target column
df['Price'].unique()
# Out:
# array([ 3897,  7662, 13882, ...,  9790, 12352, 12648], dtype=int64)

# %% [markdown]
# Above are the unique value counts of target column.

# %%
#Checking for empty observations
df.loc[df['Price'] == " "]
# Out:
# Empty DataFrame
# Columns: [Airline, Date_of_Journey, Source, Destination, Route, Dep_Time, Arrival_Time, Duration, Total_Stops, Additional_Info, Price]
# Index: []

# %% [markdown]
# There is no empty observations in my target column.

# %% [markdown]
# # Feature Extraction:

# %%
#Converting object data type to datetime 
df['Date_of_Journey'] =  pd.to_datetime(df['Date_of_Journey'])
df['Dep_Time'] =  pd.to_datetime(df['Dep_Time'])
df['Arrival_Time'] =  pd.to_datetime(df['Arrival_Time'])

# %%
#Checking the data types of all columns again
df.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time           datetime64[ns]
# Arrival_Time       datetime64[ns]
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %% [markdown]
# The data type has changed now.

# %%
#Extracting journey year,month and day from Date_of_journey

#Extracting year
df["Journey_Year"]=pd.to_datetime(df.Date_of_Journey, format="%d/%m/%Y").dt.year

#Extracting month
df["Journey_Month"]=pd.to_datetime(df.Date_of_Journey, format="%d/%m/%Y").dt.month

#Extracting day
df["Journey_Day"]=pd.to_datetime(df.Date_of_Journey, format="%d/%m/%Y").dt.day

# %%
#Droping Date_of_journey column after extraction
df = df.drop(["Date_of_Journey"],axis=1)

# %% [markdown]
# **This perticular Duration column is the difference between Arrival_time and Dep_time but the given Duration is not in format (i.e.,-h-m) so let me extract proper duration column from the Arrival_time and Dep_time.**

# %%
#Extracting Duration column using Arrival_Time and Dep_Time
Difference = (df["Arrival_Time"]-df["Dep_Time"])
Difference_list = list()
for i in range(len(Difference)):
    duration = Difference.iloc[i].seconds/3600
    Difference_list.append(duration)
df["Duration"] = Difference_list

# %%
#Extracting hours and minutes from Dep_time

#Extracting Hours
df["Dep_Hour"]=pd.to_datetime(df["Dep_Time"]).dt.hour

#Extracting Hours
df["Dep_Min"]=pd.to_datetime(df["Dep_Time"]).dt.minute

# %%
#Droping Dep_Time column after extraction
df = df.drop(["Dep_Time"],axis=1)

# %%
#Extracting hours and minutes from Arrival_Time

#Extracting Hours
df["Arrival_Hour"]=pd.to_datetime(df["Arrival_Time"]).dt.hour

#Extracting Hours
df["Arrival_Min"]=pd.to_datetime(df["Arrival_Time"]).dt.minute

# %%
#Droping Arrival_Time column after extraction
df = df.drop(["Arrival_Time"],axis=1)

# %%
#Printing the dataset after extraction
df.head()
# Out:
#        Airline    Source Destination                  Route   Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2.833333
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7.416667
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  19.000000
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5.416667
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4.750000
#
#   Total_Stops Additional_Info  Price  Journey_Year  Journey_Month  \
# 0    non-stop         No info   3897          2019              3
# 1     2 stops         No info   7662          2019              1
# 2     2 stops         No info  13882          2019              9
# 3      1 stop         No info   6218          2019             12
# 4      1 stop         No info  13302          2019              1
#
#    Journey_Day  Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 0           24        22       20             1           10
# 1            5         5       50            13           15
# 2            6         9       25             4           25
# 3            5        18        5            23           30
# 4            3        16       50            21           35

# %%
#Lets check the value counts now
for i in df.columns:
        print(df[i].value_counts())
        print('****************************************')
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64
# ****************************************
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64
# ****************************************
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64
# ****************************************
# DEL → BOM → COK                      2377
# BLR → DEL                            1552
# CCU → BOM → BLR                       979
# CCU → BLR                             724
# BOM → HYD                             621
#                                      ...
# CCU → VTZ → BLR                         1
# BLR → CCU → BBI → HYD → VGA → DEL       1
# CCU → IXA → BLR                         1
# BOM → BLR → CCU → BBI → HYD             1
# BLR → BOM → IXC → DEL                   1
# Name: Route, Length: 128, dtype: int64
# ****************************************
# 2.833333     569
# 1.500000     407
# 2.916667     381
# 2.583333     368
# 2.750000     341
#             ...
# 11.166667      2
# 19.833333      1
# 13.583333      1
# 18.083333      1
# 3.500000       1
# Name: Duration, Length: 284, dtype: int64
# ****************************************
# 1 stop      5626
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64
# ****************************************
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# Red-eye flight                     1
# 2 Long layover                     1
# 1 Short layover                    1
# Name: Additional_Info, dtype: int64
# ****************************************
# 10262    258
# 10844    212
# 7229     162
# 4804     160
# 4823     131
#         ...
# 9502       1
# 13875      1
# 7742       1
# 5703       1
# 4098       1
# Name: Price, Length: 1870, dtype: int64
# ****************************************
# 2019    10683
# Name: Journey_Year, dtype: int64
# ****************************************
# 6     2536
# 3     2211
# 5     2074
# 9     1406
# 1     1075
# 12     957
# 4      424
# Name: Journey_Month, dtype: int64
# ****************************************
# 6     2166
# 5     1392
# 3     1361
# 27    1130
# 21    1111
# 24    1052
# 15     984
# 18     832
# 4      655
# Name: Journey_Day, dtype: int64
# ****************************************
# 9     916
# 7     867
# 8     697
# 17    695
# 6     687
# 20    651
# 5     629
# 11    580
# 19    567
# 10    536
# 14    523
# 21    492
# 16    472
# 18    444
# 13    417
# 22    387
# 15    319
# 2     194
# 12    178
# 4     170
# 23    161
# 0      40
# 1      37
# 3      24
# Name: Dep_Hour, dtype: int64
# ****************************************
# 0     2062
# 30    1215
# 55    1058
# 10     890
# 45     876
# 5      773
# 15     692
# 25     691
# 20     666
# 35     665
# 50     591
# 40     504
# Name: Dep_Min, dtype: int64
# ****************************************
# 19    1626
# 12     897
# 4      838
# 21     703
# 22     647
# 1      529
# 18     514
# 9      490
# 23     485
# 10     476
# 8      471
# 7      417
# 20     377
# 16     370
# 0      322
# 13     308
# 11     298
# 14     295
# 17     191
# 15     182
# 2       79
# 5       69
# 6       52
# 3       47
# Name: Arrival_Hour, dtype: int64
# ****************************************
# 0     1447
# 25    1302
# 15    1286
# 35    1111
# 20     902
# 30     832
# 50     750
# 45     697
# 5      660
# 40     629
# 10     577
# 55     490
# Name: Arrival_Min, dtype: int64
# ****************************************

# %% [markdown]
# In Journey_Year column there is only one entry that is 2019 since all the samples are of this year.So let me drop this column.

# %%
#Droping unnecessary column
df = df.drop(["Journey_Year"],axis=1)

# %% [markdown]
# **By looking into the categorical columns i can do grouping as follows.**

# %%
#Grouping Airlines column
df["Airline"].replace("Jet Airways Business","Jet Airways",inplace=True)

df["Airline"].replace("Multiple carriers Premium economy","Multiple carriers",inplace=True)

df["Airline"].replace("Vistara Premium economy","Vistara",inplace=True)

# %%
#Grouping Destination column
df["Destination"].replace("New Delhi","Delhi",inplace=True)

# %%
#Grouping Additional_Info column
df["Additional_Info"].replace("1 Long layover","Long layover",inplace=True)

df["Additional_Info"].replace("2 Long layover","Long layover",inplace=True)

df["Additional_Info"].replace("No Info","No info",inplace=True)

# %%
#Let me assign values for Total_Stops column
df.replace({"non-stop": 0,"1 stop": 1,"2 stops": 2,"3 stops": 3,"4 stops": 4},inplace = True)

# %%
#Printing the dataset
df.head()
# Out:
#        Airline    Source Destination                  Route   Duration  \
# 0       IndiGo  Banglore       Delhi              BLR → DEL   2.833333
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7.416667
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  19.000000
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5.416667
# 4       IndiGo  Banglore       Delhi        BLR → NAG → DEL   4.750000
#
#    Total_Stops Additional_Info  Price  Journey_Month  Journey_Day  Dep_Hour  \
# 0            0         No info   3897              3           24        22
# 1            2         No info   7662              1            5         5
# 2            2         No info  13882              9            6         9
# 3            1         No info   6218             12            5        18
# 4            1         No info  13302              1            3        16
#
#    Dep_Min  Arrival_Hour  Arrival_Min
# 0       20             1           10
# 1       50            13           15
# 2       25             4           25
# 3        5            23           30
# 4       50            21           35

# %%
#Checking description of data set
df.describe()
# Out:
#            Duration   Total_Stops         Price  Journey_Month   Journey_Day  \
# count  10683.000000  10683.000000  10683.000000   10683.000000  10683.000000
# mean       8.206754      0.824207   9087.064121       5.534775     12.682205
# std        6.387288      0.675199   4611.359167       2.987489      8.803701
# min        0.000000      0.000000   1759.000000       1.000000      3.000000
# 25%        2.750000      0.000000   5277.000000       3.000000      5.000000
# 50%        6.333333      1.000000   8372.000000       5.000000      6.000000
# 75%       12.583333      1.000000  12373.000000       6.000000     21.000000
# max       23.916667      4.000000  79512.000000      12.000000     27.000000
#
#            Dep_Hour       Dep_Min  Arrival_Hour   Arrival_Min
# count  10683.000000  10683.000000  10683.000000  10683.000000
# mean      12.490686     24.411214     13.348778     24.690630
# std        5.748650     18.767980      6.859125     16.506036
# min        0.000000      0.000000      0.000000      0.000000
# 25%        8.000000      5.000000      8.000000     10.000000
# 50%       11.000000     25.000000     14.000000     25.000000
# 75%       18.000000     40.000000     19.000000     35.000000
# max       23.000000     55.000000     23.000000     55.000000

# %% [markdown]
# Above is the statistics about the dataset.The mean and the 2nd quantile values are not same so there is extreme outliers in the dataset.

# %% [markdown]
# # Visualization:

# %% [markdown]
# # Univariate Analysis:

# %%
# checking for categorical columns
categorical_columns=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_columns.append(i)
print(categorical_columns)
# Out:
# ['Airline', 'Source', 'Destination', 'Route', 'Additional_Info']

# %% [markdown]
# Above are the categorical columns in the data set.

# %%
# Now checking for numerical columns
numerical_columns=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_columns.append(i)
print(numerical_columns)
# Out:
# ['Duration', 'Total_Stops', 'Price', 'Journey_Month', 'Journey_Day', 'Dep_Hour', 'Dep_Min', 'Arrival_Hour', 'Arrival_Min']

# %% [markdown]
# Above are the numerical columns in the data set.

# %% [markdown]
# # Univariate analysis for numerical columns:

# %%
#Distribution plot for all numerical columns
for i in df[numerical_columns]:              
    plt.figure(figsize = (8, 4))
    sns.distplot(df[i], bins = 10, color="indigo")
    plt.title(i)
    plt.show()

# %% [markdown]
# There is some skewness in some of the columns i have remove that.

# %% [markdown]
# # Univariate Analysis for categorical columns:

# %%
#Checking the value counts of Airline column
df.Airline.value_counts()
# Out:
# Jet Airways          3855
# IndiGo               2053
# Air India            1752
# Multiple carriers    1209
# SpiceJet              818
# Vistara               482
# Air Asia              319
# GoAir                 194
# Trujet                  1
# Name: Airline, dtype: int64

# %%
#Count plot for Airline column
plt.figure(figsize=[10,6])
sns.countplot(df['Airline'])
plt.xticks(rotation=90);

# %% [markdown]
# - Jet Airways has maximum conut which means most of the passengers prefered Jet Airways for there travelling in the year 2019.
# - Trujet and GoAir has very less count which means only few poeple opted this airlines for there travelling in 2019.

# %%
#Checking the value counts of Source column
df.Source.value_counts()
# Out:
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %%
#Ploting pie chart for Source column
labels='Delhi','Kolkata','Banglore','Mumbai','Chennai'
fig, ax = plt.subplots()
ax.pie(df['Source'].value_counts(), labels=labels, autopct='%1.2f%%', shadow=True)
plt.show()

# %% [markdown]
# Delhi is having maximum count which means Delhi is taken as source in maximum airlines.

# %%
#Checking the value counts of Destination column
df.Destination.value_counts()
# Out:
# Cochin       4537
# Banglore     2871
# Delhi        2197
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %%
#Ploting pie chart for Destination column
labels='Cochin','Banglore','Delhi','Hyderabad','Kolkata'
fig, ax = plt.subplots()
ax.pie(df['Destination'].value_counts(), labels=labels, autopct='%1.2f%%', shadow=True)
plt.show()

# %% [markdown]
# For maximum airlines Cochin is the destination.And for few airlines kolkata is the destination.

# %%
#Checking the value counts of Route column
df.Route.value_counts()
# Out:
# DEL → BOM → COK                      2377
# BLR → DEL                            1552
# CCU → BOM → BLR                       979
# CCU → BLR                             724
# BOM → HYD                             621
#                                      ...
# CCU → VTZ → BLR                         1
# BLR → CCU → BBI → HYD → VGA → DEL       1
# CCU → IXA → BLR                         1
# BOM → BLR → CCU → BBI → HYD             1
# BLR → BOM → IXC → DEL                   1
# Name: Route, Length: 128, dtype: int64

# %%
#Count plot for Route column
plt.figure(figsize=[30,10])
sns.countplot(df['Route'])
plt.xticks(rotation=90);

# %% [markdown]
# Maximum people has choosen DEL->BOM->COK as there route.

# %%
#Checking the value counts of Additional_Info column
df.Additional_Info.value_counts()
# Out:
# No info                         8348
# In-flight meal not included     1982
# No check-in baggage included     320
# Long layover                      20
# Change airports                    7
# Business class                     4
# Red-eye flight                     1
# 1 Short layover                    1
# Name: Additional_Info, dtype: int64

# %%
#Count plot for Additional_Info column
plt.figure(figsize=[30,10])
sns.countplot(df['Additional_Info'])
plt.xticks(rotation=90,fontsize=14)
plt.yticks(rotation=0,fontsize=14);

# %% [markdown]
# In most of the flights Additional Info is No Info.

# %% [markdown]
# # Bivariate Analysis:

# %%
#Comparision between features using scatter plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Duration and Total_Stops')
sns.scatterplot(df['Duration'],df['Total_Stops'],hue=df['Price']);

# %% [markdown]
# Irrespective of Duration 1 and 2 Stops are more in count.So All the maximum airlines have maximum 1 or 2 stops.

# %%
#Comparision between features using box plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Airlines and Price')
sns.barplot(df['Airline'],df['Price'],data=df,palette="husl")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# In Air India, Multiple carriers and Jet Airways the price is high they look costly.Trujet and Spicejet are cheaper compared to other airlines.

# %%
#Comparision between features using box plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Source and Price')
sns.barplot(df['Source'],df['Price'],data=df,palette="husl")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# If Delhi is the source then the Price is more, if Chennai is the source then the Price is very less.

# %%
#Comparision between features using box plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Destination and Price')
sns.boxplot(df['Destination'],df['Price'],data=df,palette="husl")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# If Cochin is the destination then the orice is more compared to other airlines.

# %%
#Comparision between features using count plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Source and Airline')
sns.countplot(x="Source",hue="Airline",data=df,palette="husl")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Except Chennai in all other sources Jet Airways is famous.

# %%
#Comparision between features using count plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Destination and Airline')
sns.countplot(x="Destination",hue="Airline",data=df,palette="husl")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Cochin is the maximum destination with maximum count for Jet Airways which means Jet Airways is famous in those destinations.

# %%
#Comparision between features using box plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Additional_Info and Price')
sns.boxplot(df['Additional_Info'],df['Price'],data=df,palette="husl")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# For having Business class the price is very high.And for No checkin baggage included the price is very low.

# %%
#Comparision between features using box plot
plt.figure(figsize=[30,10])
plt.title('Comparision between Route and Price')
sns.barplot(df['Route'],df['Price'],data=df,palette="husl")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# BOM->JDH->DEL->HYD, BOM->DED->DEL->HYD and BOM->BOQ->DEL->HYD Routes has maximum price compared to other routes.

# %%
#Comparision between features using scatter plot
plt.figure(figsize=[20,10])
plt.title('Comparision between Duration and Price')
sns.scatterplot(df['Duration'],df['Price'],data=df,palette="husl")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# For all the Durations the price range is almost same.

# %%
#Comparision between features using box plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Total_Stops and Price')
sns.barplot(df['Total_Stops'],df['Price'],data=df,palette="husl")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# For non stop flights price is less, for 4 stops flight the price is very high.

# %%
#Comparision between features using box plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Journey_Month and Price')
sns.barplot(df['Journey_Month'],df['Price'],data=df,palette="husl")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# In Jan the Price of airlines is high and in April the price is low.Except these two in all other months the price is constant.

# %%
#Comparision between features using box plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Journey_Day and Price')
sns.boxplot(df['Journey_Day'],df['Price'],data=df,palette="husl")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# In 3rd day of each month the price is high which means it may be max weekends.And in 4th the price is low,except these two all other days the price is constant.

# %%
#Comparision between features using box plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Dep_Hour and Price')
sns.boxplot(df['Dep_Hour'],df['Price'],data=df,palette="husl")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Dep_Hour has no proper relation with price.

# %%
#Comparision between features using box plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Arrival_Hour and Price')
sns.boxplot(df['Arrival_Hour'],df['Price'],data=df,palette="husl")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Arrival_Hour has no proper relation with price.

# %% [markdown]
# # Multivariate Analysis:

# %%
#pair ploting for df
sns.pairplot(df,hue="Price")

# %% [markdown]
# Above are the pair plots of each pair of features.I can notice some outliers in each plot.I have to take care of those outliers.

# %% [markdown]
# # Checking for outliers:

# %%
#Checking for outliers using boxplot
df.plot(rot = 90,kind='box',fontsize=14,figsize=(25,25),color='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are outliers in
# - Total_Stops
# - Price
# - Journey_Month
#
# Since Price is my target i should not remove outliers from this column.And Total_Stops is a categorical column So i should not remove outliers here also.

# %% [markdown]
# # Removing Outliers:

# %% [markdown]
# # i) Zscore method:

# %%
#Features having outliers
features=df[['Journey_Month']]

# %% [markdown]
# Above are the list of columns with outliers.

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#            Airline    Source Destination                  Route   Duration  \
# 0           IndiGo  Banglore       Delhi              BLR → DEL   2.833333
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7.416667
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  19.000000
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5.416667
# 4           IndiGo  Banglore       Delhi        BLR → NAG → DEL   4.750000
# ...            ...       ...         ...                    ...        ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR   2.500000
# 10679    Air India   Kolkata    Banglore              CCU → BLR   2.583333
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL   3.000000
# 10681      Vistara  Banglore       Delhi              BLR → DEL   2.666667
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK   8.333333
#
#        Total_Stops Additional_Info  Price  Journey_Month  Journey_Day  \
# 0                0         No info   3897              3           24
# 1                2         No info   7662              1            5
# 2                2         No info  13882              9            6
# 3                1         No info   6218             12            5
# 4                1         No info  13302              1            3
# ...            ...             ...    ...            ...          ...
# 10678            0         No info   4107              9            4
# 10679            0         No info   4145              4           27
# 10680            0         No info   7229              4           27
# 10681            0         No info  12648              1            3
# 10682            2         No info  11753              9            5
#
#        Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 0            22       20             1           10
# 1             5       50            13           15
# 2             9       25             4           25
# 3            18        5            23           30
# 4            16       50            21           35
# ...         ...      ...           ...          ...
# 10678        19       55            22           25
# 10679        20       45            23           20
# 10680         8       20            11           20
# 10681        11       30            14           10
# 10682        10       55            19           15
#
# [10683 rows x 14 columns]

# %% [markdown]
# I have removed the skewness using zscore method.

# %%
#Checking shape of new dataset
df_new.shape
# Out:
# (10683, 14)

# %% [markdown]
# In my new dataset i have 10683 rows and 14 columns.

# %%
#Checking shape of old dataset
df.shape
# Out:
# (10683, 14)

# %% [markdown]
# In my old dataset i have 10683 rows and 14 columns.

# %%
#Checking dataloss in zscore method
Dataloss = (((10683-10683)/10683)*100)
Dataloss
# Out:
# 0.0

# %% [markdown]
# There is no dataloss in zscore method which means it has not removed any outliers.So let me have a look into IQR method.

# %% [markdown]
# # ii) IQR method:

# %%
# 1st quantile
Q1=features.quantile(0.25)

# 3rd quantile
Q3=features.quantile(0.75)

# IQR
IQR=Q3 - Q1

df_1=df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# I have removed the skewness using IQR method.

# %%
#Checking shape of new dataset
df_1.shape
# Out:
# (9726, 14)

# %% [markdown]
# In my new dataset i have 9726 rows and 14 columns.

# %%
#Checking shape of old dataset
df.shape
# Out:
# (10683, 14)

# %% [markdown]
# In my old dataset i have 10683 rows and 14 columns.

# %%
#Checking dataloss in IQR method
Dataloss = (((10683-9726)/10683)*100)
Dataloss
# Out:
# 8.958157820836844

# %% [markdown]
# In IQR method the data loss is less than 10% so i can use IQR method to remove outliers.

# %% [markdown]
# # Checking for skewness:

# %%
#Checking for skewness
df_1.skew()
# Out:
# Duration         0.851356
# Total_Stops      0.315096
# Price            1.892394
# Journey_Month    0.179871
# Journey_Day      0.205870
# Dep_Hour         0.123756
# Dep_Min          0.177822
# Arrival_Hour    -0.374118
# Arrival_Min      0.111059
# dtype: float64

# %% [markdown]
# There is skewness in Duration and Price.Since Price is my target i should not remove skewness in that column since i don't want my target to get manupulated.

# %% [markdown]
# # Removing skewness using yeo-johnson method:

# %%
#Creating a list of skewed features
fea=["Duration"]

# %% [markdown]
# Taking a list as fea with all the columns with skewness.

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box_cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box_cox' or 'yeo-johnson'\n"

# %% [markdown]
# Using yeo_johnson method i have removing the skewness.

# %%
df_1[fea] = scaler.fit_transform(df_1[fea].values)

# %% [markdown]
# Got removed from skewness.

# %%
#Checking skewness again
df_1[fea].skew()
# Out:
# Duration    0.000721
# dtype: float64

# %% [markdown]
# The skewness has removed now.Let me proceed.

# %%
sns.distplot(df_1['Duration'])
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Density'>

# %% [markdown]
# It looks like the skewness is reduced.

# %% [markdown]
# # Label Encoding:

# %%
# Separating categorical columns in df_1
cat_col=[]
for i in df_1.dtypes.index:
    if df_1.dtypes[i]=='object':
        cat_col.append(i)
print(cat_col)
# Out:
# ['Airline', 'Source', 'Destination', 'Route', 'Additional_Info']

# %% [markdown]
# Above are the list of categorical columns in df_1.

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df_1[cat_col]= df_1[cat_col].apply(LE.fit_transform)

# %%
df_1[cat_col].head()
# Out:
#    Airline  Source  Destination  Route  Additional_Info
# 0        3       0            2     16                6
# 1        1       3            0     78                6
# 2        4       2            1    112                6
# 4        3       0            2     27                6
# 5        6       3            0     58                6

# %% [markdown]
# Using label encoder i have encoded the categorical columns.

# %% [markdown]
# # Checking correlation using heat map:

# %%
cor=df_1.corr()

# %% [markdown]
# Checking correlation.

# %%
cor
# Out:
#                   Airline    Source  Destination     Route  Duration  \
# Airline          1.000000 -0.011183     0.060652  0.017397 -0.028970
# Source          -0.011183  1.000000    -0.428689  0.385694  0.067225
# Destination      0.060652 -0.428689     1.000000 -0.210140 -0.392358
# Route            0.017397  0.385694    -0.210140  1.000000  0.338264
# Duration        -0.028970  0.067225    -0.392358  0.338264  1.000000
# Total_Stops     -0.172712  0.189680    -0.425690  0.470162  0.621815
# Additional_Info -0.146616 -0.042452     0.076846  0.017851 -0.129913
# Price            0.020880  0.010360    -0.263846  0.170346  0.474787
# Journey_Month    0.008746  0.071145    -0.072687  0.131410  0.064575
# Journey_Day      0.025750  0.009863     0.003989  0.076424 -0.022784
# Dep_Hour        -0.024661  0.064645    -0.087151 -0.074617 -0.031530
# Dep_Min         -0.067040 -0.045119     0.091917 -0.054603 -0.041839
# Arrival_Hour    -0.014642  0.023022    -0.059000  0.016679  0.011640
# Arrival_Min     -0.083493  0.018436     0.006345 -0.177685 -0.151809
#
#                  Total_Stops  Additional_Info     Price  Journey_Month  \
# Airline            -0.172712        -0.146616  0.020880       0.008746
# Source              0.189680        -0.042452  0.010360       0.071145
# Destination        -0.425690         0.076846 -0.263846      -0.072687
# Route               0.470162         0.017851  0.170346       0.131410
# Duration            0.621815        -0.129913  0.474787       0.064575
# Total_Stops         1.000000        -0.083619  0.596254       0.076029
# Additional_Info    -0.083619         1.000000 -0.042563      -0.018736
# Price               0.596254        -0.042563  1.000000       0.013499
# Journey_Month       0.076029        -0.018736  0.013499       1.000000
# Journey_Day        -0.022166        -0.036811 -0.175841      -0.117084
# Dep_Hour           -0.060973        -0.043188  0.007035       0.015338
# Dep_Min            -0.007590        -0.007537 -0.030633      -0.027075
# Arrival_Hour        0.040415         0.030537  0.021683      -0.012621
# Arrival_Min        -0.108505         0.041405 -0.083728      -0.046453
#
#                  Journey_Day  Dep_Hour   Dep_Min  Arrival_Hour  Arrival_Min
# Airline             0.025750 -0.024661 -0.067040     -0.014642    -0.083493
# Source              0.009863  0.064645 -0.045119      0.023022     0.018436
# Destination         0.003989 -0.087151  0.091917     -0.059000     0.006345
# Route               0.076424 -0.074617 -0.054603      0.016679    -0.177685
# Duration           -0.022784 -0.031530 -0.041839      0.011640    -0.151809
# Total_Stops        -0.022166 -0.060973 -0.007590      0.040415    -0.108505
# Additional_Info    -0.036811 -0.043188 -0.007537      0.030537     0.041405
# Price              -0.175841  0.007035 -0.030633      0.021683    -0.083728
# Journey_Month      -0.117084  0.015338 -0.027075     -0.012621    -0.046453
# Journey_Day         1.000000  0.006146 -0.006040     -0.000101    -0.019700
# Dep_Hour            0.006146  1.000000 -0.030245      0.004992     0.070200
# Dep_Min            -0.006040 -0.030245  1.000000      0.044496    -0.018293
# Arrival_Hour       -0.000101  0.004992  0.044496      1.000000    -0.157420
# Arrival_Min        -0.019700  0.070200 -0.018293     -0.157420     1.000000

# %% [markdown]
# Above are the correlations of all the pair of features.To get better visualization on the correlation of features,let me plot it using heat map.

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(10,8))
sns.heatmap(df_1.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.1g', annot = True, linecolor="black",annot_kws={'size':10},cmap="coolwarm")
plt.yticks(rotation=0);

# %% [markdown]
# - There is no multicolinearity issue in any features.
# - With target Duration and total stops is higly correlated.
# - Dep_Hour is very less correlated with target.

# %%
plt.figure(figsize=(15,10))
df_1.corr()['Price'].sort_values(ascending=False).drop(['Price']).plot(kind='bar',color='g')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Dep_Hour and Source is very less correlated with target.

# %% [markdown]
# # ii) Test dataset:

# %%
#Printing test dataset
dff.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
#Checking shape of test my dataset
dff.shape
# Out:
# (2671, 10)

# %% [markdown]
# In this test dataset i have 2671 rows and 10 columns.

# %%
#Checking all column names
dff.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info'],
#       dtype='object')

# %% [markdown]
# Above are the list of column names in test dataset.

# %%
#Checking the data types of all columns
dff.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# dtype: object

# %% [markdown]
# All the columns are object type data.

# %%
#Checking the info about the dataset
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2671 non-null   object
#  1   Date_of_Journey  2671 non-null   object
#  2   Source           2671 non-null   object
#  3   Destination      2671 non-null   object
#  4   Route            2671 non-null   object
#  5   Dep_Time         2671 non-null   object
#  6   Arrival_Time     2671 non-null   object
#  7   Duration         2671 non-null   object
#  8   Total_Stops      2671 non-null   object
#  9   Additional_Info  2671 non-null   object
# dtypes: object(10)
# memory usage: 208.8+ KB

# %% [markdown]
# There is no null values.

# %%
#Checking unique values of each column
dff.nunique()
# Out:
# Airline             11
# Date_of_Journey     44
# Source               5
# Destination          6
# Route              100
# Dep_Time           199
# Arrival_Time       704
# Duration           320
# Total_Stops          5
# Additional_Info      6
# dtype: int64

# %% [markdown]
# Above are the unique value counts of all the columns.

# %%
#Lets check the value count of each column to see if there are any unexpected and unwanted entries present in the column.
for i in dff.columns:
        print(dff[i].value_counts())
        print('****************************************')
# Out:
# Jet Airways                          897
# IndiGo                               511
# Air India                            440
# Multiple carriers                    347
# SpiceJet                             208
# Vistara                              129
# Air Asia                              86
# GoAir                                 46
# Multiple carriers Premium economy      3
# Vistara Premium economy                2
# Jet Airways Business                   2
# Name: Airline, dtype: int64
# ****************************************
# 9/05/2019     144
# 12/06/2019    135
# 18/05/2019    129
# 6/06/2019     127
# 9/06/2019     119
# 21/05/2019    118
# 15/05/2019    106
# 15/06/2019    105
# 6/03/2019      97
# 21/03/2019     93
# 3/06/2019      92
# 1/06/2019      88
# 24/06/2019     85
# 24/03/2019     78
# 1/04/2019      78
# 27/06/2019     75
# 6/05/2019      73
# 24/05/2019     71
# 12/05/2019     68
# 27/05/2019     65
# 27/03/2019     65
# 1/05/2019      62
# 3/03/2019      62
# 9/03/2019      55
# 12/03/2019     43
# 18/03/2019     41
# 01/03/2019     34
# 15/03/2019     33
# 3/04/2019      28
# 06/03/2019     28
# 3/05/2019      27
# 03/03/2019     26
# 21/06/2019     24
# 9/04/2019      24
# 15/04/2019     23
# 18/06/2019     22
# 21/04/2019     22
# 09/03/2019     21
# 24/04/2019     21
# 27/04/2019     15
# 6/04/2019      14
# 18/04/2019     12
# 1/03/2019      12
# 12/04/2019     11
# Name: Date_of_Journey, dtype: int64
# ****************************************
# Delhi       1145
# Kolkata      710
# Banglore     555
# Mumbai       186
# Chennai       75
# Name: Source, dtype: int64
# ****************************************
# Cochin       1145
# Banglore      710
# Delhi         317
# New Delhi     238
# Hyderabad     186
# Kolkata        75
# Name: Destination, dtype: int64
# ****************************************
# DEL → BOM → COK                624
# BLR → DEL                      389
# CCU → BOM → BLR                253
# CCU → BLR                      172
# BOM → HYD                      164
#                               ...
# BLR → BOM → IDR → GWL → DEL      1
# CCU → BBI → IXR → DEL → BLR      1
# BLR → VGA → HYD → DEL            1
# BLR → GOI → DEL                  1
# BLR → BOM → UDR → DEL            1
# Name: Route, Length: 100, dtype: int64
# ****************************************
# 10:00    62
# 18:55    55
# 20:00    53
# 14:05    51
# 17:00    48
#          ..
# 20:10     1
# 13:50     1
# 06:25     1
# 16:35     1
# 02:30     1
# Name: Dep_Time, Length: 199, dtype: int64
# ****************************************
# 19:00           113
# 21:00           106
# 19:15           101
# 12:35            37
# 16:10            31
#                ...
# 10:55 10 Jun      1
# 05:35 10 May      1
# 10:45 07 May      1
# 16:05             1
# 19:00 04 Jun      1
# Name: Arrival_Time, Length: 704, dtype: int64
# ****************************************
# 2h 50m     122
# 1h 30m     107
# 2h 45m      95
# 2h 55m      81
# 3h          72
#           ...
# 19h 45m      1
# 31h 10m      1
# 4h 20m       1
# 38h 20m      1
# 28h 5m       1
# Name: Duration, Length: 320, dtype: int64
# ****************************************
# 1 stop      1431
# non-stop     849
# 2 stops      379
# 3 stops       11
# 4 stops        1
# Name: Total_Stops, dtype: int64
# ****************************************
# No info                         2148
# In-flight meal not included      444
# No check-in baggage included      76
# Change airports                    1
# 1 Long layover                     1
# Business class                     1
# Name: Additional_Info, dtype: int64
# ****************************************

# %% [markdown]
# Above are the value counts of each column.

# %%
#Checking null values in the dataset
dff.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %% [markdown]
# There is no null values.

# %% [markdown]
# # Feature Extraction:

# %%
#Converting object data type to datetime 
dff['Date_of_Journey'] =  pd.to_datetime(dff['Date_of_Journey'])
dff['Dep_Time'] =  pd.to_datetime(dff['Dep_Time'])
dff['Arrival_Time'] =  pd.to_datetime(dff['Arrival_Time'])

# %%
#Checking the data types of all columns again
dff.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time           datetime64[ns]
# Arrival_Time       datetime64[ns]
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# dtype: object

# %% [markdown]
# The data type has changed now.

# %%
#Extracting journey year,month and day from Date_of_journey

#Extracting year
dff["Journey_Year"]=pd.to_datetime(dff.Date_of_Journey, format="%d/%m/%Y").dt.year

#Extracting month
dff["Journey_Month"]=pd.to_datetime(dff.Date_of_Journey, format="%d/%m/%Y").dt.month

#Extracting day
dff["Journey_Day"]=pd.to_datetime(dff.Date_of_Journey, format="%d/%m/%Y").dt.day

# %%
#Droping Date_of_journey column after extraction
dff = dff.drop(["Date_of_Journey"],axis=1)

# %% [markdown]
# **This perticular Duration column is the difference between Arrival_time and Dep_time but the given Duration is not in format (i.e.,-h-m) so let me extract proper duration column from the Arrival_time and Dep_time.**

# %%
#Extracting Duration column using Arrival_Time and Dep_Time
Difference = (dff["Arrival_Time"]-dff["Dep_Time"])
Difference_list = list()
for i in range(len(Difference)):
    duration = Difference.iloc[i].seconds/3600
    Difference_list.append(duration)
dff["Duration"] = Difference_list

# %%
#Extracting hours and minutes from Dep_time

#Extracting Hours
dff["Dep_Hour"]=pd.to_datetime(dff["Dep_Time"]).dt.hour

#Extracting Hours
dff["Dep_Min"]=pd.to_datetime(dff["Dep_Time"]).dt.minute

# %%
#Droping Dep_Time column after extraction
dff = dff.drop(["Dep_Time"],axis=1)

# %%
#Extracting hours and minutes from Arrival_Time

#Extracting Hours
dff["Arrival_Hour"]=pd.to_datetime(dff["Arrival_Time"]).dt.hour

#Extracting Hours
dff["Arrival_Min"]=pd.to_datetime(dff["Arrival_Time"]).dt.minute

# %%
#Droping Arrival_Time column after extraction
dff = dff.drop(["Arrival_Time"],axis=1)

# %%
#Printing the dataset after extraction
dff.head()
# Out:
#              Airline    Source Destination            Route   Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  10.916667
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR   4.000000
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  23.750000
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK  13.000000
# 4           Air Asia  Banglore       Delhi        BLR → DEL   2.833333
#
#   Total_Stops              Additional_Info  Journey_Year  Journey_Month  \
# 0      1 stop                      No info          2019              6
# 1      1 stop                      No info          2019             12
# 2      1 stop  In-flight meal not included          2019              5
# 3      1 stop                      No info          2019              5
# 4    non-stop                      No info          2019              6
#
#    Journey_Day  Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 0            6        17       30             4           25
# 1            5         6       20            10           20
# 2           21        19       15            19            0
# 3           21         8        0            21            0
# 4           24        23       55             2           45

# %%
#Lets check the value counts now
for i in dff.columns:
        print(dff[i].value_counts())
        print('****************************************')
# Out:
# Jet Airways                          897
# IndiGo                               511
# Air India                            440
# Multiple carriers                    347
# SpiceJet                             208
# Vistara                              129
# Air Asia                              86
# GoAir                                 46
# Multiple carriers Premium economy      3
# Vistara Premium economy                2
# Jet Airways Business                   2
# Name: Airline, dtype: int64
# ****************************************
# Delhi       1145
# Kolkata      710
# Banglore     555
# Mumbai       186
# Chennai       75
# Name: Source, dtype: int64
# ****************************************
# Cochin       1145
# Banglore      710
# Delhi         317
# New Delhi     238
# Hyderabad     186
# Kolkata        75
# Name: Destination, dtype: int64
# ****************************************
# DEL → BOM → COK                624
# BLR → DEL                      389
# CCU → BOM → BLR                253
# CCU → BLR                      172
# BOM → HYD                      164
#                               ...
# BLR → BOM → IDR → GWL → DEL      1
# CCU → BBI → IXR → DEL → BLR      1
# BLR → VGA → HYD → DEL            1
# BLR → GOI → DEL                  1
# BLR → BOM → UDR → DEL            1
# Name: Route, Length: 100, dtype: int64
# ****************************************
# 2.833333     123
# 1.500000     111
# 2.750000      95
# 2.916667      91
# 2.583333      79
#             ...
# 19.250000      1
# 16.500000      1
# 3.833333       1
# 0.250000       1
# 9.916667       1
# Name: Duration, Length: 267, dtype: int64
# ****************************************
# 1 stop      1431
# non-stop     849
# 2 stops      379
# 3 stops       11
# 4 stops        1
# Name: Total_Stops, dtype: int64
# ****************************************
# No info                         2148
# In-flight meal not included      444
# No check-in baggage included      76
# Change airports                    1
# 1 Long layover                     1
# Business class                     1
# Name: Additional_Info, dtype: int64
# ****************************************
# 2019    2671
# Name: Journey_Year, dtype: int64
# ****************************************
# 6     650
# 3     545
# 5     489
# 9     363
# 1     274
# 12    257
# 4      93
# Name: Journey_Month, dtype: int64
# ****************************************
# 6     561
# 3     378
# 5     374
# 15    267
# 21    257
# 24    255
# 27    220
# 18    204
# 4     155
# Name: Journey_Day, dtype: int64
# ****************************************
# 9     236
# 7     200
# 6     176
# 8     175
# 20    175
# 17    152
# 5     147
# 19    143
# 10    141
# 11    134
# 21    133
# 16    132
# 14    124
# 15    112
# 18    109
# 22     99
# 13     94
# 12     54
# 4      49
# 2      34
# 23     28
# 0      11
# 1       7
# 3       6
# Name: Dep_Hour, dtype: int64
# ****************************************
# 0     528
# 30    276
# 55    274
# 45    230
# 10    209
# 15    184
# 5     178
# 50    176
# 25    173
# 20    153
# 35    148
# 40    142
# Name: Dep_Min, dtype: int64
# ****************************************
# 19    431
# 12    198
# 21    195
# 22    190
# 4     175
# 1     159
# 18    126
# 8     123
# 23    123
# 10    117
# 20    112
# 7     101
# 9     101
# 0      89
# 16     79
# 11     67
# 14     65
# 13     64
# 17     51
# 15     40
# 5      26
# 3      14
# 2      13
# 6      12
# Name: Arrival_Hour, dtype: int64
# ****************************************
# 0     381
# 15    326
# 25    297
# 35    254
# 30    230
# 20    204
# 45    192
# 50    185
# 5     179
# 40    156
# 10    140
# 55    127
# Name: Arrival_Min, dtype: int64
# ****************************************

# %% [markdown]
# In Journey_Year column there is only one entry that is 2019 since all the samples are of this year.So let me drop this column.

# %%
#Droping unnecessary column
dff = dff.drop(["Journey_Year"],axis=1)

# %% [markdown]
# By looking into the categorical columns i can do grouping as follows.

# %%
#Grouping Airlines column
dff["Airline"].replace("Jet Airways Business","Jet Airways",inplace=True)

dff["Airline"].replace("Multiple carriers Premium economy","Multiple carriers",inplace=True)

dff["Airline"].replace("Vistara Premium economy","Vistara",inplace=True)

# %%
#Grouping Destination column
dff["Destination"].replace("New Delhi","Delhi",inplace=True)

# %%
#Grouping Additional_Info column
dff["Additional_Info"].replace("1 Long layover","Long layover",inplace=True)

dff["Additional_Info"].replace("2 Long layover","Long layover",inplace=True)

dff["Additional_Info"].replace("No Info","No info",inplace=True)

# %%
#Let me assign values for Total_Stops column
dff.replace({"non-stop": 0,"1 stop": 1,"2 stops": 2,"3 stops": 3,"4 stops": 4},inplace = True)

# %%
#Printing the dataset
dff.head()
# Out:
#              Airline    Source Destination            Route   Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  10.916667
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR   4.000000
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  23.750000
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK  13.000000
# 4           Air Asia  Banglore       Delhi        BLR → DEL   2.833333
#
#    Total_Stops              Additional_Info  Journey_Month  Journey_Day  \
# 0            1                      No info              6            6
# 1            1                      No info             12            5
# 2            1  In-flight meal not included              5           21
# 3            1                      No info              5           21
# 4            0                      No info              6           24
#
#    Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 0        17       30             4           25
# 1         6       20            10           20
# 2        19       15            19            0
# 3         8        0            21            0
# 4        23       55             2           45

# %%
#Checking description of data set
dff.describe()
# Out:
#           Duration  Total_Stops  Journey_Month  Journey_Day     Dep_Hour  \
# count  2671.000000  2671.000000    2671.000000  2671.000000  2671.000000
# mean      8.308187     0.833396       5.607263    12.026956    12.603519
# std       6.331450     0.672315       3.042952     8.564408     5.686673
# min       0.000000     0.000000       1.000000     3.000000     0.000000
# 25%       2.833333     0.000000       3.000000     5.000000     8.000000
# 50%       6.500000     1.000000       5.000000     6.000000    12.000000
# 75%      12.583333     1.000000       6.000000    21.000000    18.000000
# max      23.916667     4.000000      12.000000    27.000000    23.000000
#
#            Dep_Min  Arrival_Hour  Arrival_Min
# count  2671.000000   2671.000000  2671.000000
# mean     24.891426     13.585174    24.558218
# std      19.086522      7.040396    16.775436
# min       0.000000      0.000000     0.000000
# 25%       5.000000      8.000000    10.000000
# 50%      25.000000     15.000000    25.000000
# 75%      45.000000     19.000000    35.000000
# max      55.000000     23.000000    55.000000

# %% [markdown]
# Above is the statistics about the dataset.The mean and the 2nd quantile values are not same so there is extreme outliers in the dataset.

# %% [markdown]
# # Checking for outliers:

# %%
#Checking for outliers using boxplot
dff.plot(rot = 90,kind='box',fontsize=14,figsize=(25,25),color='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are outliers in
#
# - Total_Stops
# - Journey_Month
#
# Since Total_Stops is a categorical column So i should not remove outliers here.

# %% [markdown]
# # Removing Outliers:

# %% [markdown]
# # i) Zscore method:

# %%
#Features having outliers
features=dff[['Journey_Month']]

# %% [markdown]
# Above are the list of columns with outliers.

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))
dff_new=dff[(z<3).all(axis=1)]
dff_new
# Out:
#                 Airline    Source Destination            Route   Duration  \
# 0           Jet Airways     Delhi      Cochin  DEL → BOM → COK  10.916667
# 1                IndiGo   Kolkata    Banglore  CCU → MAA → BLR   4.000000
# 2           Jet Airways     Delhi      Cochin  DEL → BOM → COK  23.750000
# 3     Multiple carriers     Delhi      Cochin  DEL → BOM → COK  13.000000
# 4              Air Asia  Banglore       Delhi        BLR → DEL   2.833333
# ...                 ...       ...         ...              ...        ...
# 2666          Air India   Kolkata    Banglore  CCU → DEL → BLR  23.916667
# 2667             IndiGo   Kolkata    Banglore        CCU → BLR   2.583333
# 2668        Jet Airways     Delhi      Cochin  DEL → BOM → COK   6.583333
# 2669          Air India     Delhi      Cochin  DEL → BOM → COK  15.250000
# 2670  Multiple carriers     Delhi      Cochin  DEL → BOM → COK  14.333333
#
#       Total_Stops              Additional_Info  Journey_Month  Journey_Day  \
# 0               1                      No info              6            6
# 1               1                      No info             12            5
# 2               1  In-flight meal not included              5           21
# 3               1                      No info              5           21
# 4               0                      No info              6           24
# ...           ...                          ...            ...          ...
# 2666            1                      No info              6            6
# 2667            0                      No info              3           27
# 2668            1                      No info              6            3
# 2669            1                      No info              6            3
# 2670            1                      No info              6           15
#
#       Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 0           17       30             4           25
# 1            6       20            10           20
# 2           19       15            19            0
# 3            8        0            21            0
# 4           23       55             2           45
# ...        ...      ...           ...          ...
# 2666        20       30            20           25
# 2667        14       20            16           55
# 2668        21       50             4           25
# 2669         4        0            19           15
# 2670         4       55            19           15
#
# [2671 rows x 13 columns]

# %% [markdown]
# I have removed the skewness using zscore method.

# %%
#Checking shape of new dataset
dff_new.shape
# Out:
# (2671, 13)

# %% [markdown]
# In my new test dataset i have 2671 rows and 13 columns.

# %%
#Checking shape of old dataset
dff.shape
# Out:
# (2671, 13)

# %% [markdown]
# In my old test dataset i have 2671 rows and 13 columns.

# %%
#Checking dataloss in zscore method
Dataloss = (((2671-2671)/2671)*100)
Dataloss
# Out:
# 0.0

# %% [markdown]
# There is no dataloss in zscore method which means it has not removed any outliers.So let me have a look into IQR method.

# %% [markdown]
# # ii) IQR mathod:

# %%
# 1st quantile
Q1=features.quantile(0.25)

# 3rd quantile
Q3=features.quantile(0.75)

# IQR
IQR=Q3 - Q1

dff_1=dff[~((dff < (Q1 - 1.5 * IQR)) |(dff > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# I have removed the skewness using IQR method.

# %%
#Checking shape of new dataset
dff_1.shape
# Out:
# (2414, 13)

# %% [markdown]
# In my new dataset i have 2414 rows and 13 columns.

# %%
#Checking shape of old dataset
dff.shape
# Out:
# (2671, 13)

# %% [markdown]
# In my old test dataset i have 2671 rows and 13 columns.

# %%
#Checking dataloss in IQR method
Dataloss = (((2671-2414)/2671)*100)
Dataloss
# Out:
# 9.621864470235867

# %% [markdown]
# In IQR method the data loss is less than 10% so i can use IQR method to remove outliers.

# %% [markdown]
# # Checking for skewness:

# %%
#Checking for skewness
dff_1.skew()
# Out:
# Duration         0.812134
# Total_Stops      0.327634
# Journey_Month    0.156564
# Journey_Day      0.310730
# Dep_Hour         0.107732
# Dep_Min          0.126943
# Arrival_Hour    -0.444721
# Arrival_Min      0.096564
# dtype: float64

# %% [markdown]
# There is skewness in Duration.

# %% [markdown]
# # Removing skewness using yeo-johnson method:

# %%
#Creating a list of skewed features
fea=["Duration"]

# %% [markdown]
# Taking a list as fea with all the columns with skewness.

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box_cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box_cox' or 'yeo-johnson'\n"

# %% [markdown]
# Using yeo_johnson method i have removing the skewness.

# %%
dff_1[fea] = scaler.fit_transform(dff_1[fea].values)

# %% [markdown]
# Got removed from skewness.

# %%
#Checking skewness again
dff_1[fea].skew()
# Out:
# Duration   -0.01338
# dtype: float64

# %% [markdown]
# The skewness has removed now.Let me proceed.

# %%
sns.distplot(dff_1['Duration'])
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Density'>

# %% [markdown]
# It looks like the skewness is reduced.

# %% [markdown]
# # Label Encoding:

# %%
# Separating categorical columns in dff_1
cat_col=[]
for i in dff_1.dtypes.index:
    if dff_1.dtypes[i]=='object':
        cat_col.append(i)
print(cat_col)
# Out:
# ['Airline', 'Source', 'Destination', 'Route', 'Additional_Info']

# %% [markdown]
# Above are the list of categorical columns in dff_1.

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
dff_1[cat_col]= dff_1[cat_col].apply(LE.fit_transform)

# %%
dff_1[cat_col].head()
# Out:
#    Airline  Source  Destination  Route  Additional_Info
# 0        4       2            1     70                5
# 2        4       2            1     70                2
# 3        5       2            1     70                5
# 4        0       0            2     14                5
# 7        3       3            0     52                5

# %% [markdown]
# Using label encoder i have encoded the categorical columns.

# %% [markdown]
# # Checking correlation using heat map:

# %%
cor=dff_1.corr()

# %% [markdown]
# Checking correlation.

# %%
cor
# Out:
#                   Airline    Source  Destination     Route  Duration  \
# Airline          1.000000 -0.025743     0.073316  0.006619 -0.055145
# Source          -0.025743  1.000000    -0.389236  0.330589  0.051402
# Destination      0.073316 -0.389236     1.000000 -0.229631 -0.406966
# Route            0.006619  0.330589    -0.229631  1.000000  0.360363
# Duration        -0.055145  0.051402    -0.406966  0.360363  1.000000
# Total_Stops     -0.192535  0.183536    -0.433933  0.484534  0.633328
# Additional_Info -0.149410 -0.036250     0.083267  0.040619 -0.121802
# Journey_Month   -0.002283  0.044850    -0.050412  0.129223  0.066728
# Journey_Day      0.007439 -0.025131     0.020449  0.040341 -0.052472
# Dep_Hour         0.009846  0.069805    -0.071824 -0.123306 -0.082031
# Dep_Min         -0.059759 -0.049378     0.104231 -0.036332 -0.036776
# Arrival_Hour    -0.015035  0.003893    -0.035278 -0.000204 -0.013730
# Arrival_Min     -0.108238 -0.022964     0.020444 -0.225181 -0.167460
#
#                  Total_Stops  Additional_Info  Journey_Month  Journey_Day  \
# Airline            -0.192535        -0.149410      -0.002283     0.007439
# Source              0.183536        -0.036250       0.044850    -0.025131
# Destination        -0.433933         0.083267      -0.050412     0.020449
# Route               0.484534         0.040619       0.129223     0.040341
# Duration            0.633328        -0.121802       0.066728    -0.052472
# Total_Stops         1.000000        -0.069234       0.084167    -0.038463
# Additional_Info    -0.069234         1.000000       0.033281    -0.041788
# Journey_Month       0.084167         0.033281       1.000000    -0.111535
# Journey_Day        -0.038463        -0.041788      -0.111535     1.000000
# Dep_Hour           -0.102686        -0.062081      -0.029400    -0.011166
# Dep_Min            -0.003003         0.019532      -0.009782    -0.021626
# Arrival_Hour        0.034922         0.011078       0.010870     0.017975
# Arrival_Min        -0.118665         0.022466      -0.026181    -0.017399
#
#                  Dep_Hour   Dep_Min  Arrival_Hour  Arrival_Min
# Airline          0.009846 -0.059759     -0.015035    -0.108238
# Source           0.069805 -0.049378      0.003893    -0.022964
# Destination     -0.071824  0.104231     -0.035278     0.020444
# Route           -0.123306 -0.036332     -0.000204    -0.225181
# Duration        -0.082031 -0.036776     -0.013730    -0.167460
# Total_Stops     -0.102686 -0.003003      0.034922    -0.118665
# Additional_Info -0.062081  0.019532      0.011078     0.022466
# Journey_Month   -0.029400 -0.009782      0.010870    -0.026181
# Journey_Day     -0.011166 -0.021626      0.017975    -0.017399
# Dep_Hour         1.000000 -0.041386     -0.000559     0.068546
# Dep_Min         -0.041386  1.000000      0.050686    -0.017061
# Arrival_Hour    -0.000559  0.050686      1.000000    -0.136125
# Arrival_Min      0.068546 -0.017061     -0.136125     1.000000

# %% [markdown]
# Above are the correlations of all the pair of features.To get better visualization on the correlation of features,let me plot it using heat map.

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(10,8))
sns.heatmap(dff_1.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.1g', annot = True, linecolor="black",annot_kws={'size':10},cmap="coolwarm")
plt.yticks(rotation=0);

# %% [markdown]
# There is no multicolinearity issue in any features.

# %% [markdown]
# # Scaling the data using standard scaler:

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_1 = pd.DataFrame(scaler.fit_transform(dff_1), columns=dff_1.columns)

# %% [markdown]
# I have scaled my data using standard scaler.

# %%
X_1.head()
# Out:
#     Airline    Source  Destination     Route  Duration  Total_Stops  \
# 0  0.243561  0.042047    -0.184755  0.784578  0.679728     0.258811
# 1  0.243561  0.042047    -0.184755  0.784578  1.735062     0.258811
# 2  0.825697  0.042047    -0.184755  0.784578  0.909146     0.258811
# 3 -2.084982 -1.649655     0.845266 -1.413788 -0.885227    -1.228737
# 4 -0.338574  0.887898    -1.214777  0.077960 -0.221330     0.258811
#
#    Additional_Info  Journey_Month  Journey_Day  Dep_Hour   Dep_Min  \
# 0         0.463204       0.460712    -0.778303  0.787794  0.270961
# 1        -2.246426       0.031473     0.948874  1.140228 -0.512706
# 2         0.463204       0.031473     0.948874 -0.798160 -1.296373
# 3         0.463204       0.460712     1.294310  1.845097  1.577073
# 4         0.463204      -1.685484    -0.893448  0.435360 -0.512706
#
#    Arrival_Hour  Arrival_Min
# 0     -1.357442     0.016725
# 1      0.768368    -1.467637
# 2      1.051809    -1.467637
# 3     -1.640883     1.204215
# 4      0.910089     0.313598

# %% [markdown]
# # Checking for multicolinearity issue using VIF:

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X_1.values, i) for i in range(X_1.shape[1])]
vif["Features"]=X_1.columns
vif
# Out:
#     vif_Features         Features
# 0       1.108317          Airline
# 1       1.353865           Source
# 2       1.540213      Destination
# 3       1.582325            Route
# 4       1.873648         Duration
# 5       2.150076      Total_Stops
# 6       1.068353  Additional_Info
# 7       1.032979    Journey_Month
# 8       1.028633      Journey_Day
# 9       1.048960         Dep_Hour
# 10      1.023057          Dep_Min
# 11      1.030572     Arrival_Hour
# 12      1.109045      Arrival_Min

# %% [markdown]
# There is no multicolinearity issue in this dataset.

# %% [markdown]
# **Now my test dataset is ready for prediction.**

# %% [markdown]
# # MODEL BUILDING FROM TRAIN DATASET:

# %% [markdown]
# # Separating features and label in train dataset:

# %%
x = df_1.drop("Price",axis=1)
y = df_1["Price"]

# %% [markdown]
# I have separated my target and independent columns.

# %% [markdown]
# # Scaling the data using standard scaler:

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# %% [markdown]
# I have scaled my data using standard scaler.

# %%
X.head()
# Out:
#     Airline    Source  Destination     Route  Duration  Total_Stops  \
# 0 -0.341739 -1.669916     0.813802 -1.561573 -0.848535    -1.215953
# 1 -1.459531  0.906072    -1.178405  0.206403  0.232876     1.748418
# 2  0.217157  0.047409    -0.182302  1.175939  1.420381     1.748418
# 3 -0.341739 -1.669916     0.813802 -1.247899 -0.290740     0.266233
# 4  1.334949  0.906072    -1.178405 -0.363911 -1.006944    -1.215953
#
#    Additional_Info  Journey_Month  Journey_Day  Dep_Hour   Dep_Min  \
# 0         0.504758      -0.825893     1.190880  1.662506 -0.225703
# 1         0.504758      -1.695886    -0.948377 -1.295187  1.375647
# 2         0.504758       1.784083    -0.835785 -0.599259  0.041189
# 3         0.504758      -1.695886    -1.173562  0.618614  1.375647
# 4         0.504758       0.479095     1.190880 -0.599259 -1.293269
#
#    Arrival_Hour  Arrival_Min
# 0     -1.789294    -0.887038
# 1     -0.048504    -0.584070
# 2     -1.354097     0.021868
# 3      1.112022     0.627805
# 4     -0.338636     0.021868

# %% [markdown]
# This is the data of independent variables after scaling.

# %% [markdown]
# # Checking for multicolinearity issue using VIF:

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features         Features
# 0       1.095758          Airline
# 1       1.484266           Source
# 2       1.595172      Destination
# 3       1.621352            Route
# 4       1.802938         Duration
# 5       2.099914      Total_Stops
# 6       1.063287  Additional_Info
# 7       1.039366    Journey_Month
# 8       1.031428      Journey_Day
# 9       1.032383         Dep_Hour
# 10      1.021972          Dep_Min
# 11      1.036265     Arrival_Hour
# 12      1.093988      Arrival_Min

# %% [markdown]
# There is no multicolinearity issue in this dataset.

# %% [markdown]
# # Finding Best Random State and Accuracy:

# %%
#importing necessary libraries
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestRegressor
maxAccu=0
maxRS=0
for i in range(1,200):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.30, random_state =i)
    mod = RandomForestRegressor()
    mod.fit(X_train, y_train)
    pred = mod.predict(X_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.9142029268300772  on Random_state  141

# %% [markdown]
# I got the best accuracy and random state.

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.30,random_state=maxRS)

# %% [markdown]
# Created train test split.

# %% [markdown]
# # Regression Algorithms:

# %%
#importing necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import SGDRegressor
from xgboost import XGBRegressor
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingRegressor
from sklearn import metrics

# %% [markdown]
# # i) RandomForestRegressor:

# %%
RFR=RandomForestRegressor()
RFR.fit(X_train,y_train)
pred=RFR.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.9124861070093417
# mean_squared_error: 1796616.5695521245
# mean_absolute_error: 658.5676843171012
# root_mean_squared_error: 1340.3792633251696

# %% [markdown]
# RFR is giving me 91.25% r2_score.

# %% [markdown]
# # ii) XGB Regressor:

# %%
XGB=XGBRegressor()
XGB.fit(X_train,y_train)
pred=XGB.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8978698180732748
# mean_squared_error: 2096681.6905347125
# mean_absolute_error: 766.7195644993093
# root_mean_squared_error: 1447.9922964348646

# %% [markdown]
# XGB is giving me 89.79% r2_score.

# %% [markdown]
# # iii) ExtraTreeRegressor:

# %%
ETR=ExtraTreesRegressor()
ETR.fit(X_train,y_train)
pred=ETR.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.9049543003217975
# mean_squared_error: 1951240.8038431297
# mean_absolute_error: 652.2826347955221
# root_mean_squared_error: 1396.8682127685238

# %% [markdown]
# ETR is giving me 90.50% r2_score.

# %% [markdown]
# # iv) Gradient Boosting:

# %%
GBR=GradientBoostingRegressor()
GBR.fit(X_train,y_train)
pred=GBR.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8191560226984984
# mean_squared_error: 3712636.6456839973
# mean_absolute_error: 1279.3704284008052
# root_mean_squared_error: 1926.820345980392

# %% [markdown]
# GBR is giving me 81.92% r2_score.

# %% [markdown]
# # v) DecisionTreeRegressor:

# %%
DTR=DecisionTreeRegressor()
DTR.fit(X_train,y_train)
pred=DTR.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8381217664750905
# mean_squared_error: 3323279.38641383
# mean_absolute_error: 723.6569568197395
# root_mean_squared_error: 1822.986392273357

# %% [markdown]
# DTR is giving me 83.81% r2_score.

# %% [markdown]
# # vi) KNN:

# %%
knn=KNN()
knn.fit(X_train,y_train)
pred=knn.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.7068627116423043
# mean_squared_error: 6017962.3076901985
# mean_absolute_error: 1457.583002056203
# root_mean_squared_error: 2453.1535434395864

# %% [markdown]
# KNN is giving me 70.69% r2_score.

# %% [markdown]
# # Cross Validation Score:

# %%
print(cross_val_score(RFR,X,y,cv=5).mean())
# Out:
# 0.8867852407784025

# %%
print(cross_val_score(XGB,X,y,cv=5).mean())
# Out:
# 0.8931060434463524

# %%
print(cross_val_score(ETR,X,y,cv=5).mean())
# Out:
# 0.8894760028267255

# %%
print(cross_val_score(GBR,X,y,cv=5).mean())
# Out:
# 0.8114507227105863

# %%
print(cross_val_score(DTR,X,y,cv=5).mean())
# Out:
# 0.8092320101641294

# %%
print(cross_val_score(knn,X,y,cv=5).mean())
# Out:
# 0.7096126835433072

# %% [markdown]
# Above are the cross validation scores of RFR,XGB,ETR,GBR,DTR and KNN.
#
# By looking into the difference of model accuracy and cross validation score i got least difference for XGB.So XGB is my best model.And i have to tune it to get better accuracy.

# %% [markdown]
# # Hyper Parameter Tuning:

# %%
#importing necessary libraries
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'gamma':np.arange(0,0.5,0.1),
             'n_estimators':[10,100,1000],
             'max_depth': [2,4,6,8,10],
              'n_jobs':[-2,-1,1,2]}

# %% [markdown]
# Giving XGB parameters.

# %%
GCV=GridSearchCV(XGBRegressor(verbosity=0),parameter,cv=5)

# %% [markdown]
# Running grid search CV for XGB.

# %%
GCV.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n_estimators=100, n_jobs=None,
#                                     num_parallel_tree=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None,
#                                     scale_pos_weight=None, subsample=None,
#                                     tree_method=None, validate_parameters=None,
#                                     verbosity=0),
#              param_grid={'gamma': array([0. , 0.1, 0.2, 0.3, 0.4]),
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'n_estimators': [10, 100, 1000],
#                          'n_jobs': [-2, -1, 1, 2]})

# %% [markdown]
# Tunning the model using GCV.

# %%
GCV.best_params_
# Out:
# {'gamma': 0.0, 'max_depth': 6, 'n_estimators': 100, 'n_jobs': -2}

# %% [markdown]
# Got the best parameters for XGB.

# %%
Best_mod=XGBRegressor(gamma=0.0,max_depth=6,n_estimators=100,n_jobs=-2)
Best_mod.fit(X_train,y_train)
pred=Best_mod.predict(X_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# R2_Score: 89.78698180732748
# mean_squared_error: 2096681.6905347125
# mean_absolute_error: 766.7195644993093
# RMSE value: 1447.9922964348646

# %% [markdown]
# This is my model after tuning.I got 89.79% as r2_score which is gooddd!!!.But the accuracy has not increased it has remained same.

# %% [markdown]
# # Saving the model:

# %%
# Saving the model using .pkl
import joblib
joblib.dump(Best_mod,"Flight_Price.pkl")
# Out:
# ['Flight_Price.pkl']

# %% [markdown]
# I have saved my model as Flight_Price.Using .pkl

# %% [markdown]
# # Predicting Flight Price for test dataset using Saved model of trained dataset:

# %%
# Loading the saved model
model=joblib.load("Flight_Price.pkl")

#Prediction
prediction = model.predict(X_test)
prediction
# Out:
# array([14666.968 ,  9372.992 ,  4057.144 , ...,  6701.6646,  5325.328 ,
#        10362.227 ], dtype=float32)

# %%
pd.DataFrame([model.predict(X_test)[:],y_test[:]],index=["Predicted","Actual"])
# Out:
#                    0            1            2            3            4     \
# Predicted  14666.967773  9372.992188  4057.144043  6771.487305  6165.588379
# Actual     14781.000000  8372.000000  3540.000000  5704.000000  5438.000000
#
#                    5             6            7             8            9     \
# Predicted  10997.473633  11889.890625  6244.836914  10815.638672  7631.388672
# Actual     11150.000000  12273.000000  5761.000000  10844.000000  7690.000000
#
#            ...          2908          2909         2910          2911  \
# Predicted  ...  13589.700195  14658.829102  2716.795166  13816.366211
# Actual     ...  14588.000000  14714.000000  2754.000000  13885.000000
#
#                    2912         2913         2914         2915         2916  \
# Predicted  17292.197266  5857.026855  4999.969238  6701.664551  5325.328125
# Actual     17471.000000  6347.000000  4995.000000  4959.000000  6015.000000
#
#                    2917
# Predicted  10362.226562
# Actual      9103.000000
#
# [2 rows x 2918 columns]

# %% [markdown]
# Above are the predicted values and the actual values.They are almost similar.

# %%
plt.figure(figsize=(10,5))
plt.scatter(y_test, prediction, c='crimson')
p1 = max(max(prediction), max(y_test))
p2 = min(min(prediction), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('Actual', fontsize=15)
plt.ylabel('Predicted', fontsize=15)
plt.title("XGBRegressor")
plt.show()

# %% [markdown]
# Plotting Actual vs Predicted,To get better insight.Bule line is the actual line and red dots are the predicted values.

# %%
#Predicting flight price using cleaned test dataset dff_1
Predicted_Flight_Price=model.predict(dff_1)
Predicted_Flight_Price
# Out:
# array([5976.585 , 8214.709 , 6874.1416, ..., 3886.9187, 7043.4834,
#        7078.814 ], dtype=float32)

# %%
#Making dataframe for predicted Price
Flight_Price_Predictions=pd.DataFrame()
Flight_Price_Predictions["Price"]=Predicted_Flight_Price
Flight_Price_Predictions
# Out:
#              Price
# 0      5976.584961
# 1      8214.708984
# 2      6874.141602
# 3     12472.263672
# 4      6427.555664
# ...            ...
# 2409   8561.624023
# 2410   4791.748535
# 2411   3886.918701
# 2412   7043.483398
# 2413   7078.813965
#
# [2414 rows x 1 columns]

# %%
#Lets save the predictions to csv
Flight_Price_Predictions.to_csv("Flight_Price_Predictions.csv",index=False)

# %% [markdown]
# I have saved the predicted values as csv file.

# %% [markdown]
# # Done:

# %% [markdown]
# # Thank You:) For Evaluating My Project:)

# %% [markdown]
# # Stay Safe:)
